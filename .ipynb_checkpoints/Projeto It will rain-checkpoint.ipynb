# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sklearn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 import numpy as np
#       3 import seaborn as sns
# ----> 4 import sklearn
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
chuva = pd.read_csv('rain_data_aus.csv')

# %%
chuva.head()
# Out:
#          date location  mintemp  maxtemp  rainfall  evaporation  sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#    humidity9am  humidity3pm  pressure9am  ...  temp9am  temp3pm  raintoday  \
# 0         71.0         22.0       1007.7  ...     16.9     21.8         No
# 1         44.0         25.0       1010.6  ...     17.2     24.3         No
# 2         38.0         30.0       1007.6  ...     21.0     23.2         No
# 3         45.0         16.0       1017.6  ...     18.1     26.5         No
# 4         82.0         33.0       1010.8  ...     17.8     29.7         No
#
#    amountOfRain  raintomorrow   temp   humidity precipitation3pm  \
# 0           0.0            No  29.48  28.400000               12
# 1           0.0            No  32.12   2.208569               10
# 2           0.0            No  32.84  38.000000               17
# 3           1.0            No  35.60  21.200000                8
# 4           0.2            No  40.76  41.600000                9
#
#    precipitation9am  modelo_vigente
# 0          5.115360        0.089825
# 1         21.497100        0.023477
# 2         20.782859        0.027580
# 3         12.028646        0.023962
# 4         11.883546        0.220164
#
# [5 rows x 23 columns]

# %%
chuva.shape
# Out:
# (142193, 23)

# %%
chuva.describe()
# Out:
#              mintemp        maxtemp       rainfall   evaporation  \
# count  141556.000000  141871.000000  140787.000000  81350.000000
# mean       12.186400      23.226784       2.349974      5.469824
# std         6.403283       7.117618       8.465173      4.188537
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.800000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            sunshine    humidity9am    humidity3pm    pressure9am  \
# count  74377.000000  140419.000000  138583.000000  128179.000000
# mean       7.624853      68.843810      51.482606    1017.653758
# std        3.781525      19.051293      20.797772       7.105476
# min        0.000000       0.000000       0.000000     980.500000
# 25%        4.900000      57.000000      37.000000    1012.900000
# 50%        8.500000      70.000000      52.000000    1017.600000
# 75%       10.600000      83.000000      66.000000    1022.400000
# max       14.500000     100.000000     100.000000    1041.000000
#
#          pressure3pm      cloud9am      cloud3pm        temp9am  \
# count  128212.000000  88536.000000  85099.000000  141289.000000
# mean     1015.258204      4.437189      4.503167      16.987509
# std         7.036677      2.887016      2.720633       6.492838
# min       977.100000      0.000000      0.000000      -7.200000
# 25%      1010.400000      1.000000      2.000000      12.300000
# 50%      1015.200000      5.000000      5.000000      16.700000
# 75%      1020.000000      7.000000      7.000000      21.600000
# max      1039.600000      9.000000      9.000000      40.200000
#
#              temp3pm   amountOfRain           temp       humidity  \
# count  139467.000000  142193.000000  141871.000000  138583.000000
# mean       21.687235       2.360682      28.505419      61.991179
# std         6.937594       8.477969      10.237506      26.649111
# min        -5.400000       0.000000      -3.760000       2.000000
# 25%        16.600000       0.000000      22.520000      44.000000
# 50%        21.100000       0.000000      28.520000      63.200000
# 75%        26.400000       0.800000      35.480000      80.000000
# max        46.700000     371.000000      59.720000     122.000000
#
#        precipitation3pm  precipitation9am  modelo_vigente
# count     142193.000000     142193.000000   142193.000000
# mean          10.014164         10.000748        0.227804
# std            3.169832          4.997908        0.272764
# min            0.000000        -17.739346        0.000000
# 25%            8.000000          6.650238        0.030055
# 50%           10.000000         10.000009        0.100853
# 75%           12.000000         13.389306        0.329507
# max           26.000000         32.478590        0.999400

# %%
chuva.describe(include = 'object')
# Out:
#               date  location raintoday raintomorrow
# count       142193    142193    140787       142193
# unique        3436        49         2            2
# top     2013-12-01  Canberra        No           No
# freq            49      3418    109332       110316

# %%
chuva.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142193 entries, 0 to 142192
# Data columns (total 23 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   date              142193 non-null  object
#  1   location          142193 non-null  object
#  2   mintemp           141556 non-null  float64
#  3   maxtemp           141871 non-null  float64
#  4   rainfall          140787 non-null  float64
#  5   evaporation       81350 non-null   float64
#  6   sunshine          74377 non-null   float64
#  7   humidity9am       140419 non-null  float64
#  8   humidity3pm       138583 non-null  float64
#  9   pressure9am       128179 non-null  float64
#  10  pressure3pm       128212 non-null  float64
#  11  cloud9am          88536 non-null   float64
#  12  cloud3pm          85099 non-null   float64
#  13  temp9am           141289 non-null  float64
#  14  temp3pm           139467 non-null  float64
#  15  raintoday         140787 non-null  object
#  16  amountOfRain      142193 non-null  float64
#  17  raintomorrow      142193 non-null  object
#  18  temp              141871 non-null  float64
#  19  humidity          138583 non-null  float64
#  20  precipitation3pm  142193 non-null  int64
#  21  precipitation9am  142193 non-null  float64
#  22  modelo_vigente    142193 non-null  float64
# dtypes: float64(18), int64(1), object(4)
# memory usage: 25.0+ MB

# %%
sns.set({'figure.figsize':(20,20)})
sns.heatmap(chuva.isnull(),cbar=False)
# Out:
# <Axes: >

# %%
chuva = pd.get_dummies(chuva, drop_first = True, columns = ['raintoday', 'raintomorrow'])

# %%
chuva.columns
# Out:
# Index(['date', 'location', 'mintemp', 'maxtemp', 'rainfall', 'evaporation',
#        'sunshine', 'humidity9am', 'humidity3pm', 'pressure9am', 'pressure3pm',
#        'cloud9am', 'cloud3pm', 'temp9am', 'temp3pm', 'amountOfRain', 'temp',
#        'humidity', 'precipitation3pm', 'precipitation9am', 'modelo_vigente',
#        'raintoday_Yes', 'raintomorrow_Yes'],
#       dtype='object')

# %%
chuva
# Out:
#               date location  mintemp  maxtemp  rainfall  evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 142188  2017-06-20    Uluru      3.5     21.8       0.0          NaN
# 142189  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 142190  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 142191  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 142192  2017-06-24    Uluru      7.8     27.0       0.0          NaN
#
#         sunshine  humidity9am  humidity3pm  pressure9am  ...  temp9am  \
# 0            NaN         71.0         22.0       1007.7  ...     16.9
# 1            NaN         44.0         25.0       1010.6  ...     17.2
# 2            NaN         38.0         30.0       1007.6  ...     21.0
# 3            NaN         45.0         16.0       1017.6  ...     18.1
# 4            NaN         82.0         33.0       1010.8  ...     17.8
# ...          ...          ...          ...          ...  ...      ...
# 142188       NaN         59.0         27.0       1024.7  ...      9.4
# 142189       NaN         51.0         24.0       1024.6  ...     10.1
# 142190       NaN         56.0         21.0       1023.5  ...     10.9
# 142191       NaN         53.0         24.0       1021.0  ...     12.5
# 142192       NaN         51.0         24.0       1019.4  ...     15.1
#
#         temp3pm  amountOfRain   temp   humidity  precipitation3pm  \
# 0          21.8           0.0  29.48  28.400000                12
# 1          24.3           0.0  32.12   2.208569                10
# 2          23.2           0.0  32.84  38.000000                17
# 3          26.5           1.0  35.60  21.200000                 8
# 4          29.7           0.2  40.76  41.600000                 9
# ...         ...           ...    ...        ...               ...
# 142188     20.9           0.0  28.16  34.400000                12
# 142189     22.4           0.0  30.08  30.800000                10
# 142190     24.5           0.0  32.36  27.200000                 9
# 142191     26.1           0.0  34.28  30.800000                12
# 142192     26.0           0.0  34.40  30.800000                15
#
#         precipitation9am  modelo_vigente  raintoday_Yes  raintomorrow_Yes
# 0               5.115360        0.089825              0                 0
# 1              21.497100        0.023477              0                 0
# 2              20.782859        0.027580              0                 0
# 3              12.028646        0.023962              0                 0
# 4              11.883546        0.220164              0                 0
# ...                  ...             ...            ...               ...
# 142188          5.848681        0.002556              0                 0
# 142189          6.653879        0.002053              0                 0
# 142190         19.715976        0.023350              0                 0
# 142191          0.985551        0.007195              0                 0
# 142192          4.381481        0.018811              0                 0
#
# [142193 rows x 23 columns]

# %%
chuva.corr()['raintomorrow_Yes'].sort_values(ascending = False)
# Out:
# /var/folders/4x/z7f3ppt51xv6ltctr39t5prh0000gn/T/ipykernel_40672/294739921.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   chuva.corr()['raintomorrow_Yes'].sort_values(ascending = False)
# raintomorrow_Yes    1.000000
# modelo_vigente      0.825086
# amountOfRain        0.501485
# humidity3pm         0.446160
# humidity            0.405600
# cloud3pm            0.381870
# cloud9am            0.317380
# raintoday_Yes       0.306555
# humidity9am         0.257161
# rainfall            0.239032
# mintemp             0.083936
# precipitation3pm    0.004503
# precipitation9am   -0.007018
# temp9am            -0.025691
# evaporation        -0.119285
# temp               -0.125976
# maxtemp            -0.159237
# temp3pm            -0.192424
# pressure3pm        -0.226031
# pressure9am        -0.246371
# sunshine           -0.450768
# Name: raintomorrow_Yes, dtype: float64

# %%
vento = pd.read_csv('wind_table_01.csv')

# %%
vento
# Out:
#              date       location wind_gustdir  wind_gustspeed wind_dir9am  \
# 0      2007-11-01       Canberra           NW            30.0          SW
# 1      2007-11-02       Canberra          ENE            39.0           E
# 2      2007-11-03       Canberra           NW            85.0           N
# 3      2007-11-04       Canberra           NW            54.0         WNW
# 4      2007-11-05       Canberra          SSE            50.0         SSE
# ...           ...            ...          ...             ...         ...
# 19995  2010-01-25      Newcastle          NaN             NaN          SE
# 19996  2010-01-25      NorahHead           NE            37.0         SSW
# 19997  2010-01-25  NorfolkIsland            S            28.0           E
# 19998  2010-01-25       Richmond          ENE            33.0         NaN
# 19999  2010-01-25         Sydney          NaN             NaN         WNW
#
#       wind_dir3pm  wind_speed9am  wind_speed3pm
# 0              NW            6.0           20.0
# 1               W            4.0           17.0
# 2             NNE            6.0            6.0
# 3               W           30.0           24.0
# 4             ESE           20.0           28.0
# ...           ...            ...            ...
# 19995          SE            6.0            6.0
# 19996         NaN           11.0            NaN
# 19997         SSE            6.0           13.0
# 19998           E            NaN           11.0
# 19999           E            2.0           19.0
#
# [20000 rows x 8 columns]

# %%
vento.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            20000 non-null  object
#  1   location        20000 non-null  object
#  2   wind_gustdir    17866 non-null  object
#  3   wind_gustspeed  17869 non-null  float64
#  4   wind_dir9am     18564 non-null  object
#  5   wind_dir3pm     19470 non-null  object
#  6   wind_speed9am   19614 non-null  float64
#  7   wind_speed3pm   19609 non-null  float64
# dtypes: float64(3), object(5)
# memory usage: 1.2+ MB

# %%
sns.scatterplot(x='modelo_vigente', y='humidity', hue = 'raintomorrow_Yes', data=chuva)
# Out:
# <Axes: xlabel='modelo_vigente', ylabel='humidity'>

# %%
sns.boxplot(x='raintomorrow_Yes', y='modelo_vigente', data=chuva)
# Out:
# <Axes: xlabel='raintomorrow_Yes', ylabel='modelo_vigente'>

# %%
from sklearn.linear_model import LinearRegression
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 from sklearn.linear_model import LinearRegression
#
# ModuleNotFoundError: No module named 'sklearn'
